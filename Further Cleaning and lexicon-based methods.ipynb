# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
import nltk
import os

# Ensure NLTK data path and required resources
nltk_data_dir = os.path.expanduser("~/nltk_data")
os.makedirs(nltk_data_dir, exist_ok=True)
if nltk_data_dir not in nltk.data.path:
    nltk.data.path.append(nltk_data_dir)

# Download resources if missing
for pkg in [
    'punkt',
    'averaged_perceptron_tagger',
    'wordnet',
    'stopwords',
    'omw-1.4'
]:
    try:
        nltk.data.find(f"tokenizers/{pkg}" if pkg == 'punkt' else f"taggers/{pkg}" if pkg == 'averaged_perceptron_tagger' else f"corpora/{pkg}")
    except LookupError:
        nltk.download(pkg)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/trinhthanh2508/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/trinhthanh2508/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df=pd.read_csv('clean_datasets/clean_all.csv')
df.head()
len(df)
# Out:
# 77321

# %%
#tokenization
def tweet_token(text):
    words_set=text.str.split()
    tokens=[word for word in words_set]
    return tokens

df['tokens']=tweet_token(df['clean_tweet'])
df.head()
# Out:
#    created_at              user_id         username  \
# 0  2021-01-06            293175196        sjtafalla
# 1  2021-01-06           1591779799        ellieelif
# 2  2021-01-06            215143656     danananarama
# 3  2021-01-06            336462129  veronica_foote_
# 4  2021-01-06  1063705581133934593           5herii
#
#                                                tweet place    near  \
# 0  UK Parliament: 2nd Covid Vaccine should be 21 ...   NaN  London
# 1  First dose of vaccination 💉 5/1/2021..to comba...   NaN  London
# 2  Time to forget about #COVID, #Brexit and #Trum...   NaN  London
# 3  @doctor_oxford Rachel you absolutely nailed it...   NaN  London
# 4  My kids can never say they don’t wanna do thei...   NaN  London
#
#                                          clean_tweet  \
# 0  parliament covid vaccine should days not weeks...
# 1           dose vaccination syringe combating covid
# 2  time forget covid brexit trump sleep listening...
# 3  rachel absolutely nailed tonight program conti...
# 4  kids never not wana homework sparkles covid sp...
#
#                                               tokens
# 0  [parliament, covid, vaccine, should, days, not...
# 1     [dose, vaccination, syringe, combating, covid]
# 2  [time, forget, covid, brexit, trump, sleep, li...
# 3  [rachel, absolutely, nailed, tonight, program,...
# 4  [kids, never, not, wana, homework, sparkles, c...

# %%
#lemmatize and stemming
import nltk
word_tokenizer = nltk.tokenize.WhitespaceTokenizer()
word_lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [word_lemmatizer.lemmatize(word) for word in word_tokenizer.tokenize(text)]
df['lemma']=df['clean_tweet'].apply(lemmatize_text)
df.head()
# Out:
#    created_at              user_id         username  \
# 0  2021-01-06            293175196        sjtafalla
# 1  2021-01-06           1591779799        ellieelif
# 2  2021-01-06            215143656     danananarama
# 3  2021-01-06            336462129  veronica_foote_
# 4  2021-01-06  1063705581133934593           5herii
#
#                                                tweet place    near  \
# 0  UK Parliament: 2nd Covid Vaccine should be 21 ...   NaN  London
# 1  First dose of vaccination 💉 5/1/2021..to comba...   NaN  London
# 2  Time to forget about #COVID, #Brexit and #Trum...   NaN  London
# 3  @doctor_oxford Rachel you absolutely nailed it...   NaN  London
# 4  My kids can never say they don’t wanna do thei...   NaN  London
#
#                                          clean_tweet  \
# 0  parliament covid vaccine should days not weeks...
# 1           dose vaccination syringe combating covid
# 2  time forget covid brexit trump sleep listening...
# 3  rachel absolutely nailed tonight program conti...
# 4  kids never not wana homework sparkles covid sp...
#
#                                               tokens  \
# 0  [parliament, covid, vaccine, should, days, not...
# 1     [dose, vaccination, syringe, combating, covid]
# 2  [time, forget, covid, brexit, trump, sleep, li...
# 3  [rachel, absolutely, nailed, tonight, program,...
# 4  [kids, never, not, wana, homework, sparkles, c...
#
#                                                lemma
# 0  [parliament, covid, vaccine, should, day, not,...
# 1     [dose, vaccination, syringe, combating, covid]
# 2  [time, forget, covid, brexit, trump, sleep, li...
# 3  [rachel, absolutely, nailed, tonight, program,...
# 4  [kid, never, not, wana, homework, sparkle, cov...

# %%
#lemma_sentence
df['lemma_sentence'] = df['lemma'].apply(lambda x: ' '.join(x))
df.head()
# Out:
#    created_at              user_id         username  \
# 0  2021-01-06            293175196        sjtafalla
# 1  2021-01-06           1591779799        ellieelif
# 2  2021-01-06            215143656     danananarama
# 3  2021-01-06            336462129  veronica_foote_
# 4  2021-01-06  1063705581133934593           5herii
#
#                                                tweet place    near  \
# 0  UK Parliament: 2nd Covid Vaccine should be 21 ...   NaN  London
# 1  First dose of vaccination 💉 5/1/2021..to comba...   NaN  London
# 2  Time to forget about #COVID, #Brexit and #Trum...   NaN  London
# 3  @doctor_oxford Rachel you absolutely nailed it...   NaN  London
# 4  My kids can never say they don’t wanna do thei...   NaN  London
#
#                                          clean_tweet  \
# 0  parliament covid vaccine should days not weeks...
# 1           dose vaccination syringe combating covid
# 2  time forget covid brexit trump sleep listening...
# 3  rachel absolutely nailed tonight program conti...
# 4  kids never not wana homework sparkles covid sp...
#
#                                               tokens  \
# 0  [parliament, covid, vaccine, should, days, not...
# 1     [dose, vaccination, syringe, combating, covid]
# 2  [time, forget, covid, brexit, trump, sleep, li...
# 3  [rachel, absolutely, nailed, tonight, program,...
# 4  [kids, never, not, wana, homework, sparkles, c...
#
#                                                lemma  \
# 0  [parliament, covid, vaccine, should, day, not,...
# 1     [dose, vaccination, syringe, combating, covid]
# 2  [time, forget, covid, brexit, trump, sleep, li...
# 3  [rachel, absolutely, nailed, tonight, program,...
# 4  [kid, never, not, wana, homework, sparkle, cov...
#
#                                       lemma_sentence
# 0  parliament covid vaccine should day not week c...
# 1           dose vaccination syringe combating covid
# 2  time forget covid brexit trump sleep listening...
# 3  rachel absolutely nailed tonight program conti...
# 4  kid never not wana homework sparkle covid spar...

# %%
#POS for clean tweets
#reference:
#https://www.machinelearningplus.com/nlp/lemmatization-examples-python/
#https://stackoverflow.com/questions/51267166/lemmatization-pandas-python
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
stem_lemmatizer = WordNetLemmatizer()

# Safe tokenization helper: fall back to simple split if punkt not available
def safe_word_tokenize(text):
    try:
        return word_tokenize(text)
    except LookupError:
        return text.split()

def convert_wordnet_tag(tag):
    if tag and tag.startswith('J'):
        return wordnet.ADJ
    elif tag and tag.startswith('V'):
        return wordnet.VERB
    elif tag and tag.startswith('N'):
        return wordnet.NOUN
    elif tag and tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def pos_tag_set(tweet):
    # Use safe tokenization and handle tagger availability
    tokens = safe_word_tokenize(tweet)
    try:
        tagged_words = pos_tag(tokens)
    except LookupError:
        # If tagger not available, return tokens with None POS
        tagged_words = [(w, None) for w in tokens]
    new_tag = []
    for word, tag in tagged_words:
        new_tag.append((word, convert_wordnet_tag(tag) if tag else None))
    return new_tag

df['pos_tag'] = df['clean_tweet'].apply(pos_tag_set)
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 77316  2021-05-20  1161700993840680961     PhilipCrook9
# 77317  2021-05-19            146596633     edwardjsault
# 77318  2021-05-19            235304684        phoTomics
# 77319  2021-05-17   726443182997835778     SarahClift10
# 77320  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 77316  Very little interest by politicians and media ...
# 77317  #BREAKING Health Secretary Matt Hancock has an...
# 77318  “Hundreds of flights full of Indian corona” co...
# 77319  Sadiq Khan asks for vaccine blitz in variant-h...
# 77320  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77316  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77317  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77318  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77319  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77320  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                        near  \
# 0                    London
# 1                    London
# 2                    London
# 3                    London
# 4                    London
# ...                     ...
# 77316  Southampton, England
# 77317  Southampton, England
# 77318  Southampton, England
# 77319  Southampton, England
# 77320  Southampton, England
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kids never not wana homework sparkles covid sp...
# ...                                                  ...
# 77316  very politicians media china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318       hundreds flights indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kids, never, not, wana, homework, sparkles, c...
# ...                                                  ...
# 77316  [very, politicians, media, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundreds, flights, indian, corona, pretty, ra...
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kid, never, not, wana, homework, sparkle, cov...
# ...                                                  ...
# 77316  [very, politician, medium, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundred, flight, indian, corona, pretty, racist]
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kid never not wana homework sparkle covid spar...
# ...                                                  ...
# 77316  very politician medium china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318         hundred flight indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                  pos_tag
# 0      [(parliament, n), (covid, n), (vaccine, n), (s...
# 1      [(dose, a), (vaccination, n), (syringe, n), (c...
# 2      [(time, n), (forget, v), (covid, a), (brexit, ...
# 3      [(rachel, n), (absolutely, r), (nailed, a), (t...
# 4      [(kids, n), (never, r), (not, r), (wana, a), (...
# ...                                                  ...
# 77316  [(very, r), (politicians, n), (media, n), (chi...
# 77317  [(breaking, v), (health, n), (secretary, n), (...
# 77318  [(hundreds, n), (flights, n), (indian, a), (co...
# 77319  [(sadiq, n), (khan, n), (vaccine, n), (blitz, ...
# 77320  [(not, r), (covid, a), (reality, n), (brexit, ...
#
# [77321 rows x 11 columns]

# %%
#create lemma sentence with pos-tags
def handle_lemma(pos_tweet):
    lemma_set = " "
    for word, pos in pos_tweet:
        if not pos: 
            lemma = word
            lemma_set = lemma_set + " " + lemma
        else:  
            lemma = stem_lemmatizer.lemmatize(word, pos=pos)
            lemma_set = lemma_set + " " + lemma
    return lemma_set
df['pos_tag'].apply(handle_lemma)
    
df['lemma_sentence(with POS)'] = df['pos_tag'].apply(handle_lemma)
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 77316  2021-05-20  1161700993840680961     PhilipCrook9
# 77317  2021-05-19            146596633     edwardjsault
# 77318  2021-05-19            235304684        phoTomics
# 77319  2021-05-17   726443182997835778     SarahClift10
# 77320  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 77316  Very little interest by politicians and media ...
# 77317  #BREAKING Health Secretary Matt Hancock has an...
# 77318  “Hundreds of flights full of Indian corona” co...
# 77319  Sadiq Khan asks for vaccine blitz in variant-h...
# 77320  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77316  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77317  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77318  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77319  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77320  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                        near  \
# 0                    London
# 1                    London
# 2                    London
# 3                    London
# 4                    London
# ...                     ...
# 77316  Southampton, England
# 77317  Southampton, England
# 77318  Southampton, England
# 77319  Southampton, England
# 77320  Southampton, England
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kids never not wana homework sparkles covid sp...
# ...                                                  ...
# 77316  very politicians media china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318       hundreds flights indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kids, never, not, wana, homework, sparkles, c...
# ...                                                  ...
# 77316  [very, politicians, media, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundreds, flights, indian, corona, pretty, ra...
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kid, never, not, wana, homework, sparkle, cov...
# ...                                                  ...
# 77316  [very, politician, medium, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundred, flight, indian, corona, pretty, racist]
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kid never not wana homework sparkle covid spar...
# ...                                                  ...
# 77316  very politician medium china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318         hundred flight indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, n), (covid, n), (vaccine, n), (s...
# 1      [(dose, a), (vaccination, n), (syringe, n), (c...
# 2      [(time, n), (forget, v), (covid, a), (brexit, ...
# 3      [(rachel, n), (absolutely, r), (nailed, a), (t...
# 4      [(kids, n), (never, r), (not, r), (wana, a), (...
# ...                                                  ...
# 77316  [(very, r), (politicians, n), (media, n), (chi...
# 77317  [(breaking, v), (health, n), (secretary, n), (...
# 77318  [(hundreds, n), (flights, n), (indian, a), (co...
# 77319  [(sadiq, n), (khan, n), (vaccine, n), (blitz, ...
# 77320  [(not, r), (covid, a), (reality, n), (brexit, ...
#
#                                 lemma_sentence(with POS)
# 0        parliament covid vaccine should day not week...
# 1                  dose vaccination syringe combat covid
# 2        time forget covid brexit trump sleep listeni...
# 3        rachel absolutely nailed tonight program con...
# 4        kid never not wana homework sparkle covid sp...
# ...                                                  ...
# 77316    very politician medium china economy thrive ...
# 77317    break health secretary matt hancock announce...
# 77318         hundred flight indian corona pretty racist
# 77319    sadiq khan vaccine blitz variant hit london ...
# 77320                   not covid reality brexit reality
#
# [77321 rows x 12 columns]

# %%
#save as csv
df.to_csv('Further_clean_datasets/further_clean_all.csv',index = False, encoding='utf_8_sig')

# %%
#split into 3 steps
import datetime
df['created_at'] = pd.to_datetime(df['created_at'] , utc=True).dt.date
further_step_one = df[(df['created_at']) < datetime.date(2021,3,8)].reset_index(drop=True)
print("step_one:",len(further_step_one))
# Out:
# step_one: 29920

# %%
further_step_two = df[((df['created_at']) >= datetime.date(2021,3,8)) & ((df['created_at']) < datetime.date(2021,5,17))].reset_index(drop=True)
print("step_two:",len(further_step_two))
# Out:
# step_two: 24682

# %%
further_step_three= df[((df['created_at']) >= datetime.date(2021,5,17)) & ((df['created_at']) <= datetime.date(2021,7,18))].reset_index(drop=True)
print("step_three:",len(further_step_three))
len(further_step_one)+len(further_step_two)+len(further_step_three)
# Out:
# step_three: 22719
# 77321

# %%
further_step_one.to_csv('Further_clean_datasets/further_clean_step1.csv',index = False, encoding='utf_8_sig')
further_step_two.to_csv('Further_clean_datasets/further_clean_step2.csv',index = False, encoding='utf_8_sig')
further_step_three.to_csv('Further_clean_datasets/further_clean_step3.csv',index = False, encoding='utf_8_sig')

# %%
#sentiwordnet analysis
#reference: https://github.com/harika-bonthu/Lexicon-based-SentimentAnalysis/blob/main/lexicon_based_sentiment_analysis.ipynb
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet as swn
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
#和之前的方法结果 有差距

def sentiwordnetanalysis(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue

        synset = synsets[0] #only take the most common meaning
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
    if not tokens_count:
        return 0
    else:
        return sentiment

df['sentiword_analysis']=df['pos_tag'].apply(sentiwordnetanalysis)
df
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     /home/trinhthanh2508/nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 77316  2021-05-20  1161700993840680961     PhilipCrook9
# 77317  2021-05-19            146596633     edwardjsault
# 77318  2021-05-19            235304684        phoTomics
# 77319  2021-05-17   726443182997835778     SarahClift10
# 77320  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 77316  Very little interest by politicians and media ...
# 77317  #BREAKING Health Secretary Matt Hancock has an...
# 77318  “Hundreds of flights full of Indian corona” co...
# 77319  Sadiq Khan asks for vaccine blitz in variant-h...
# 77320  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77316  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77317  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77318  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77319  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77320  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                        near  \
# 0                    London
# 1                    London
# 2                    London
# 3                    London
# 4                    London
# ...                     ...
# 77316  Southampton, England
# 77317  Southampton, England
# 77318  Southampton, England
# 77319  Southampton, England
# 77320  Southampton, England
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kids never not wana homework sparkles covid sp...
# ...                                                  ...
# 77316  very politicians media china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318       hundreds flights indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kids, never, not, wana, homework, sparkles, c...
# ...                                                  ...
# 77316  [very, politicians, media, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundreds, flights, indian, corona, pretty, ra...
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kid, never, not, wana, homework, sparkle, cov...
# ...                                                  ...
# 77316  [very, politician, medium, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundred, flight, indian, corona, pretty, racist]
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kid never not wana homework sparkle covid spar...
# ...                                                  ...
# 77316  very politician medium china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318         hundred flight indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, n), (covid, n), (vaccine, n), (s...
# 1      [(dose, a), (vaccination, n), (syringe, n), (c...
# 2      [(time, n), (forget, v), (covid, a), (brexit, ...
# 3      [(rachel, n), (absolutely, r), (nailed, a), (t...
# 4      [(kids, n), (never, r), (not, r), (wana, a), (...
# ...                                                  ...
# 77316  [(very, r), (politicians, n), (media, n), (chi...
# 77317  [(breaking, v), (health, n), (secretary, n), (...
# 77318  [(hundreds, n), (flights, n), (indian, a), (co...
# 77319  [(sadiq, n), (khan, n), (vaccine, n), (blitz, ...
# 77320  [(not, r), (covid, a), (reality, n), (brexit, ...
#
#                                 lemma_sentence(with POS)  sentiword_analysis
# 0        parliament covid vaccine should day not week...              -0.625
# 1                  dose vaccination syringe combat covid              -0.125
# 2        time forget covid brexit trump sleep listeni...               0.250
# 3        rachel absolutely nailed tonight program con...               0.625
# 4        kid never not wana homework sparkle covid sp...              -0.875
# ...                                                  ...                 ...
# 77316    very politician medium china economy thrive ...               0.250
# 77317    break health secretary matt hancock announce...               0.750
# 77318         hundred flight indian corona pretty racist              -0.125
# 77319    sadiq khan vaccine blitz variant hit london ...               0.000
# 77320                   not covid reality brexit reality              -0.625
#
# [77321 rows x 13 columns]

# %%
#VADER--low speed--use further clean datasets
sentiment_analyzer = SentimentIntensityAnalyzer()
def vaderSentiment_method(df):
    sentiment_analyzer = SentimentIntensityAnalyzer()
    snt_score = sentiment_analyzer.polarity_scores(df['lemma_sentence(with POS)'])
    return snt_score['compound'] 

df['vader_score'] = df.apply(vaderSentiment_method, axis=1)
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 77316  2021-05-20  1161700993840680961     PhilipCrook9
# 77317  2021-05-19            146596633     edwardjsault
# 77318  2021-05-19            235304684        phoTomics
# 77319  2021-05-17   726443182997835778     SarahClift10
# 77320  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 77316  Very little interest by politicians and media ...
# 77317  #BREAKING Health Secretary Matt Hancock has an...
# 77318  “Hundreds of flights full of Indian corona” co...
# 77319  Sadiq Khan asks for vaccine blitz in variant-h...
# 77320  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77316  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77317  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77318  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77319  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77320  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                        near  \
# 0                    London
# 1                    London
# 2                    London
# 3                    London
# 4                    London
# ...                     ...
# 77316  Southampton, England
# 77317  Southampton, England
# 77318  Southampton, England
# 77319  Southampton, England
# 77320  Southampton, England
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kids never not wana homework sparkles covid sp...
# ...                                                  ...
# 77316  very politicians media china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318       hundreds flights indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kids, never, not, wana, homework, sparkles, c...
# ...                                                  ...
# 77316  [very, politicians, media, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundreds, flights, indian, corona, pretty, ra...
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kid, never, not, wana, homework, sparkle, cov...
# ...                                                  ...
# 77316  [very, politician, medium, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundred, flight, indian, corona, pretty, racist]
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kid never not wana homework sparkle covid spar...
# ...                                                  ...
# 77316  very politician medium china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318         hundred flight indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, n), (covid, n), (vaccine, n), (s...
# 1      [(dose, a), (vaccination, n), (syringe, n), (c...
# 2      [(time, n), (forget, v), (covid, a), (brexit, ...
# 3      [(rachel, n), (absolutely, r), (nailed, a), (t...
# 4      [(kids, n), (never, r), (not, r), (wana, a), (...
# ...                                                  ...
# 77316  [(very, r), (politicians, n), (media, n), (chi...
# 77317  [(breaking, v), (health, n), (secretary, n), (...
# 77318  [(hundreds, n), (flights, n), (indian, a), (co...
# 77319  [(sadiq, n), (khan, n), (vaccine, n), (blitz, ...
# 77320  [(not, r), (covid, a), (reality, n), (brexit, ...
#
#                                 lemma_sentence(with POS)  sentiword_analysis  \
# 0        parliament covid vaccine should day not week...              -0.625
# 1                  dose vaccination syringe combat covid              -0.125
# 2        time forget covid brexit trump sleep listeni...               0.250
# 3        rachel absolutely nailed tonight program con...               0.625
# 4        kid never not wana homework sparkle covid sp...              -0.875
# ...                                                  ...                 ...
# 77316    very politician medium china economy thrive ...               0.250
# 77317    break health secretary matt hancock announce...               0.750
# 77318         hundred flight indian corona pretty racist              -0.125
# 77319    sadiq khan vaccine blitz variant hit london ...               0.000
# 77320                   not covid reality brexit reality              -0.625
#
#        vader_score
# 0          -0.0572
# 1          -0.3400
# 2          -0.2263
# 3           0.0000
# 4           0.0634
# ...            ...
# 77316      -0.7485
# 77317       0.0000
# 77318      -0.2023
# 77319       0.0000
# 77320       0.0000
#
# [77321 rows x 14 columns]

# %%
#Textblob
from textblob import TextBlob

def Polarity_score(tweet):
    return TextBlob(tweet).sentiment.polarity

def Subjectivity_score(tweet):
    return TextBlob(tweet).sentiment.subjectivity

df['textblob_polarity'] = df['lemma_sentence(with POS)'].apply(Polarity_score) 
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 77316  2021-05-20  1161700993840680961     PhilipCrook9
# 77317  2021-05-19            146596633     edwardjsault
# 77318  2021-05-19            235304684        phoTomics
# 77319  2021-05-17   726443182997835778     SarahClift10
# 77320  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 77316  Very little interest by politicians and media ...
# 77317  #BREAKING Health Secretary Matt Hancock has an...
# 77318  “Hundreds of flights full of Indian corona” co...
# 77319  Sadiq Khan asks for vaccine blitz in variant-h...
# 77320  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 77316  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77317  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77318  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77319  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 77320  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                        near  \
# 0                    London
# 1                    London
# 2                    London
# 3                    London
# 4                    London
# ...                     ...
# 77316  Southampton, England
# 77317  Southampton, England
# 77318  Southampton, England
# 77319  Southampton, England
# 77320  Southampton, England
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kids never not wana homework sparkles covid sp...
# ...                                                  ...
# 77316  very politicians media china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318       hundreds flights indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kids, never, not, wana, homework, sparkles, c...
# ...                                                  ...
# 77316  [very, politicians, media, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundreds, flights, indian, corona, pretty, ra...
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1         [dose, vaccination, syringe, combating, covid]
# 2      [time, forget, covid, brexit, trump, sleep, li...
# 3      [rachel, absolutely, nailed, tonight, program,...
# 4      [kid, never, not, wana, homework, sparkle, cov...
# ...                                                  ...
# 77316  [very, politician, medium, china, economy, thr...
# 77317  [breaking, health, secretary, matt, hancock, a...
# 77318  [hundred, flight, indian, corona, pretty, racist]
# 77319  [sadiq, khan, vaccine, blitz, variant, hit, lo...
# 77320             [not, covid, reality, brexit, reality]
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1               dose vaccination syringe combating covid
# 2      time forget covid brexit trump sleep listening...
# 3      rachel absolutely nailed tonight program conti...
# 4      kid never not wana homework sparkle covid spar...
# ...                                                  ...
# 77316  very politician medium china economy thriving ...
# 77317  breaking health secretary matt hancock announc...
# 77318         hundred flight indian corona pretty racist
# 77319  sadiq khan vaccine blitz variant hit london bo...
# 77320                   not covid reality brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, n), (covid, n), (vaccine, n), (s...
# 1      [(dose, a), (vaccination, n), (syringe, n), (c...
# 2      [(time, n), (forget, v), (covid, a), (brexit, ...
# 3      [(rachel, n), (absolutely, r), (nailed, a), (t...
# 4      [(kids, n), (never, r), (not, r), (wana, a), (...
# ...                                                  ...
# 77316  [(very, r), (politicians, n), (media, n), (chi...
# 77317  [(breaking, v), (health, n), (secretary, n), (...
# 77318  [(hundreds, n), (flights, n), (indian, a), (co...
# 77319  [(sadiq, n), (khan, n), (vaccine, n), (blitz, ...
# 77320  [(not, r), (covid, a), (reality, n), (brexit, ...
#
#                                 lemma_sentence(with POS)  sentiword_analysis  \
# 0        parliament covid vaccine should day not week...              -0.625
# 1                  dose vaccination syringe combat covid              -0.125
# 2        time forget covid brexit trump sleep listeni...               0.250
# 3        rachel absolutely nailed tonight program con...               0.625
# 4        kid never not wana homework sparkle covid sp...              -0.875
# ...                                                  ...                 ...
# 77316    very politician medium china economy thrive ...               0.250
# 77317    break health secretary matt hancock announce...               0.750
# 77318         hundred flight indian corona pretty racist              -0.125
# 77319    sadiq khan vaccine blitz variant hit london ...               0.000
# 77320                   not covid reality brexit reality              -0.625
#
#        vader_score  textblob_polarity
# 0          -0.0572           0.000000
# 1          -0.3400           0.000000
# 2          -0.2263           0.000000
# 3           0.0000           0.300000
# 4           0.0634           0.025000
# ...            ...                ...
# 77316      -0.7485          -0.005556
# 77317       0.0000           0.000000
# 77318      -0.2023           0.250000
# 77319       0.0000           0.000000
# 77320       0.0000           0.000000
#
# [77321 rows x 15 columns]

# %%
##save as csv
df.to_csv('unsupervised_datasets/lexicon_all.csv',index = False, encoding='utf_8_sig')

# %%
#split into 3 steps
import datetime
df['created_at'] = pd.to_datetime(df['created_at'] , utc=True).dt.date
lexicon_step_one = df[(df['created_at']) < datetime.date(2021,3,8)].reset_index(drop=True)
print("step_one:",len(lexicon_step_one))
# Out:
# step_one: 29920

# %%
lexicon_step_two = df[((df['created_at']) >= datetime.date(2021,3,8)) & ((df['created_at']) < datetime.date(2021,5,17))].reset_index(drop=True)
print("step_two:",len(lexicon_step_two))
# Out:
# step_two: 24682

# %%
lexicon_step_three= df[((df['created_at']) >= datetime.date(2021,5,17)) & ((df['created_at']) <= datetime.date(2021,7,18))].reset_index(drop=True)
print("step_three:",len(lexicon_step_three))
# Out:
# step_three: 22719

# %%
#merge three datasets
dfs=[lexicon_step_one,lexicon_step_two,lexicon_step_three]
dfs=pd.concat(dfs)
dfs=dfs.reset_index(drop=True)

# %%
lexicon_step_one.to_csv('unsupervised_datasets/lexicon_step1.csv',index = False, encoding='utf_8_sig')
lexicon_step_two.to_csv('unsupervised_datasets/lexicon_step2.csv',index = False, encoding='utf_8_sig')
lexicon_step_three.to_csv('unsupervised_datasets/lexicon_step3.csv',index = False, encoding='utf_8_sig')
